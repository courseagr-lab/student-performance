# %%
from pathlib import Path
import sys

import pandas as pd
import numpy as np

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.data.data_cleaning import load_config, load_raw, clean_categorical

config = load_config()

# %%
import sys
sys.path.append("..")

from src.data.data_cleaning import load_config, load_raw, run_cleaning

config = load_config("config/config.yaml")   # path relatif ke PROJECT_ROOT, bukan ../
df_raw = load_raw(config)
df_raw.info()
df_raw.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   student_id          508 non-null    int64
#  1   hours_studied       488 non-null    float64
#  2   attendance_rate     508 non-null    object
#  3   sleep_hours         482 non-null    float64
#  4   previous_score      498 non-null    float64
#  5   parental_education  426 non-null    object
#  6   extracurricular     508 non-null    object
#  7   gender              508 non-null    object
#  8   passed              508 non-null    int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 35.8+ KB
#    student_id  hours_studied attendance_rate  sleep_hours  previous_score  \
# 0        1273            7.3            87.6          5.1            55.7
# 1        1031            3.8            87.7          6.2            67.1
# ...

# %%
df_cleaned = run_cleaning(config)
df_cleaned.info()
df_cleaned.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 0 to 507
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   student_id          500 non-null    int64
#  1   hours_studied       500 non-null    float64
#  2   attendance_rate     500 non-null    float64
#  3   sleep_hours         500 non-null    float64
#  4   previous_score      500 non-null    float64
#  5   parental_education  500 non-null    string
#  6   extracurricular     500 non-null    string
#  7   gender              500 non-null    string
#  8   passed              500 non-null    int64
# dtypes: float64(4), int64(2), string(3)
# memory usage: 39.1 KB
#    student_id  hours_studied  attendance_rate  sleep_hours  previous_score  \
# 0        1273            7.3             87.6          5.1            55.7
# 1        1031            3.8             87.7          6.2            67.1
# ...

# %%
print(df_raw["gender"].value_counts(dropna=False))
print(df_raw["extracurricular"].value_counts(dropna=False))
print(df_raw["parental_education"].value_counts(dropna=False))
print("Missing:\n", df_raw.isnull().sum())
# Out:
# gender
# Male      175
# Female    145
# M          55
# F          55
# male       34
# female     28
# m           8
# f           8
# Name: count, dtype: int64
# extracurricular
# No     233
# Yes    174
# no      67
# yes     34
# Name: count, dtype: int64
# parental_education
# High School    139
# Bachelor       138
# NaN             82
# Master          76
# HIGH SCHOOL     35
# BACHELOR        24
# MASTER          12
# NONE             2
# Name: count, dtype: int64
# Missing:
#  student_id             0
# hours_studied         20
# attendance_rate        0
# sleep_hours           26
# previous_score        10
# parental_education    82
# extracurricular        0
# gender                 0
# passed                 0
# dtype: int64

# %%
df_cleaned = run_cleaning(config)
df_cleaned.info()
print(df_cleaned["gender"].unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 0 to 507
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   student_id          500 non-null    int64
#  1   hours_studied       500 non-null    float64
#  2   attendance_rate     500 non-null    float64
#  3   sleep_hours         500 non-null    float64
#  4   previous_score      500 non-null    float64
#  5   parental_education  500 non-null    string
#  6   extracurricular     500 non-null    string
#  7   gender              500 non-null    string
#  8   passed              500 non-null    int64
# dtypes: float64(4), int64(2), string(3)
# memory usage: 39.1 KB
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: string
